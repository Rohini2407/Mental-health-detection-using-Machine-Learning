# %%
import pandas as pd

# %%
df = pd.read_csv("Datasets/Stage-1.csv")

# %%
df
# Out:
#    Have you ever experienced a terrible occurrence that has impacted you significantly? Examples may include being the victim of armed assault, witnessing a tragedy happen to someone else, surviving a sexual assault, or living through a natural disaster  \
# 0                                                  No
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10                                                 No
# 11                                                 No
# 12                                                 No
# ...

# %%
df.columns
# Out:
# Index(['Have you ever experienced a terrible occurrence that has impacted you significantly? Examples may include being the victim of armed assault, witnessing a tragedy happen to someone else, surviving a sexual assault, or living through a natural disaster',
#        'Do you ever feel that you’ve been affected by feelings of edginess, anxiety, or nerves?',
#        'Have you ever experienced an ‘attack’ of fear, anxiety, or panic?',
#        'Do feelings of anxiety or discomfort around others bother you?',
#        'Have you experienced a week or longer of lower-than-usual interest in activities that you usually enjoy? Examples might include work, exercise, or hobbies.',
#        'Answers'],
#       dtype='object')

# %%
df.columns[0]
# Out:
# 'Have you ever experienced a terrible occurrence that has impacted you significantly? Examples may include being the victim of armed assault, witnessing a tragedy happen to someone else, surviving a sexual assault, or living through a natural disaster'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
proc_df = df.loc[:, df.columns !='Answers']

# %%
proc_df
# Out:
#    Have you ever experienced a terrible occurrence that has impacted you significantly? Examples may include being the victim of armed assault, witnessing a tragedy happen to someone else, surviving a sexual assault, or living through a natural disaster  \
# 0                                                  No
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10                                                 No
# 11                                                 No
# 12                                                 No
# ...

# %%
proc_df.loc[len(proc_df)] = ['Yes', 'Yes', 'No', 'No', 'No']
# Out:
# C:\Users\jayat\AppData\Local\Temp\ipykernel_18128\2253450046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proc_df.loc[len(proc_df)] = ['Yes', 'Yes', 'No', 'No', 'No']

# %%
proc_df
# Out:
#    Have you ever experienced a terrible occurrence that has impacted you significantly? Examples may include being the victim of armed assault, witnessing a tragedy happen to someone else, surviving a sexual assault, or living through a natural disaster  \
# 0                                                  No
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10                                                 No
# 11                                                 No
# 12                                                 No
# ...

# %%
dup_df = proc_df[proc_df.duplicated(keep=False)]
dup_df
# Out:
#    Have you ever experienced a terrible occurrence that has impacted you significantly? Examples may include being the victim of armed assault, witnessing a tragedy happen to someone else, surviving a sexual assault, or living through a natural disaster  \
# 24                                                Yes
# 32                                                Yes
#
#    Do you ever feel that you’ve been affected by feelings of edginess, anxiety, or nerves?  \
# 24                                                Yes
# 32                                                Yes
#
#    Have you ever experienced an ‘attack’ of fear, anxiety, or panic?  \
# 24                                                 No
# 32                                                 No
#
#    Do feelings of anxiety or discomfort around others bother you?  \
# 24                                                 No
# 32                                                 No
#
# ...

# %%
dup_df.index[0]
# Out:
# 24

# %%
df.iloc[dup_df.index[0]]['Answers']
# Out:
# 'Do some Excersise'
